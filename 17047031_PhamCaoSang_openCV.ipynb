# %% [markdown]
# <a href="https://colab.research.google.com/github/Sang3105/DPT/blob/main/17047031_PhamCaoSang_openCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt 
import numpy as np 
x = np.uint8([250])
y = np.uint8([10])
print (cv2.add(x,y)) # 250+10 = 260 => 255
print (x+y)
# Out:
# [[255]]
# [4]

# %%
import cv2
from matplotlib import pyplot as plt 
import numpy as np 
img1 = cv2.imread('/content/Images/download.jpg')
img2 = cv2.imread('/content/Images/download (1).jpg')
dst = cv2.addWeighted(img1,0.6,img2,0.4,0)
cv2_imshow(dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=184x274 at 0x7F5BE009EE10>

# %%
import cv2
from matplotlib import pyplot as plt 
import numpy as np
# Load two images
img2 = cv2.imread('/content/Images/download.jpg')
img1 = cv2.imread('/content/Images/1200px-OpenCV_Logo_with_text_svg_version.svg_.png')
# I want to put logo on top-left corner, So I create a ROI
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols ]
# Now create a mask of logo and create its inverse mask also
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(img2gray, 10, 255, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)
# Now black-out the area of logo in ROI
img1_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)
# Take only region of logo from logo image.
img2_fg = cv2.bitwise_and(img2,img2,mask = mask)
# Put logo in ROI and modify the main image
dst = cv2.add(img1_bg,img2_fg)
img1[0:rows, 0:cols ] = dst
cv2_imshow(img1)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1478 at 0x7F5BDE8800F0>

# %%
import cv2
from matplotlib import pyplot as plt 
import numpy as np
img1 = cv2.imread('/content/Images/opencv_logo.png')
e1 = cv2.getTickCount()
for i in range(5,49,2):
  img1 = cv2.medianBlur(img1,i)
e2 = cv2.getTickCount()
t = (e2 - e1)/cv2.getTickFrequency()
print (t)
# Out:
# 0.376703542

# %%
In [5]: cv2.useOptimized()
Out[5]: True
In [6]: %timeit res = cv2.medianBlur(img,49)
# Disable it
In [7]: cv2.setUseOptimized(False)
In [8]: cv2.useOptimized()
Out[8]: False
In [9]: %timeit res = cv2.medianBlur(img,49)
# Out:
# 100 loops, best of 3: 17.4 ms per loop
# 100 loops, best of 3: 17.3 ms per loop

# %%
In [10]: x = 5
In [11]: %timeit y=x**2

In [12]: %timeit y=x*x

In [15]: z = np.uint8([5])
In [17]: %timeit y=z*z
# Out:
# The slowest run took 6.51 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 3: 227 ns per loop
# 10000000 loops, best of 3: 44.1 ns per loop
# The slowest run took 128.87 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 3: 522 ns per loop
