# %% [markdown]
# <a href="https://colab.research.google.com/github/Sang3105/DPT/blob/main/17047031_PhamCaoSang_TK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# define range of blue color in HSV
cl = np.uint8([[[ 255,255,0]]])
hsv = cv2.cvtColor(cl, cv2.COLOR_BGR2HSV)
print(hsv)
low=hsv[0][0][0]-10,100,100
up=hsv[0][0][0]+10,255,255
print(low)
print(up)
# Out:
# [[[ 90 255 255]]]
# (80, 100, 100)
# (100, 255, 255)

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Take each frame
frame = cv2.imread('/content/drive/MyDrive/Colab Notebooks/image/Color).png')
# Convert BGR to HSV
hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
# define range of blue color in HSV
lower_blue = np.array([110,50,50])
upper_blue = np.array([130,255,255])
# Threshold the HSV image to get only blue colors
mask = cv2.inRange(hsv, lower_blue, upper_blue)
# Bitwise-AND mask and original image
res = cv2.bitwise_and(frame,frame, mask= mask)
cv2_imshow(frame)
cv2_imshow(mask)
cv2_imshow(res)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x7FBFA33532E8>
# <PIL.Image.Image image mode=L size=480x480 at 0x7FBF992BC7B8>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x7FBF992BC828>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Take each frame
frame = cv2.imread('/content/drive/MyDrive/Colab Notebooks/image/Color).png')
# Convert BGR to HSV
hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
# define range of blue color in HSV
lower_green = np.array([80,100,100])
upper_green = np.array([100,255,255])
# Threshold the HSV image to get only blue colors
mask = cv2.inRange(hsv, lower_green, upper_green)
# Bitwise-AND mask and original image
res = cv2.bitwise_and(frame,frame, mask= mask)
cv2_imshow(frame)
cv2_imshow(mask)
cv2_imshow(res)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x7FBF8FAC3780>
# <PIL.Image.Image image mode=L size=480x480 at 0x7FBF8FAB8358>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x7FBF8FAB8438>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Take each frame
frame = cv2.imread('/content/drive/MyDrive/Colab Notebooks/image/Color).png')
# Convert BGR to HSV
hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
# define range of blue color in HSV
lower_yellow = np.array([110,50,50])
upper_yellow = np.array([130,255,255])
# Threshold the HSV image to get only blue colors
mask = cv2.inRange(hsv, lower_yellow, upper_yellow)
# Bitwise-AND mask and original image
res = cv2.bitwise_and(frame,frame, mask= mask)
cv2_imshow(frame)
cv2_imshow(mask)
cv2_imshow(res)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x7FBF979CDCC0>
# <PIL.Image.Image image mode=L size=480x480 at 0x7FBF8FA4A2E8>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x7FBF8FA4A278>

# %%
import cv2
from matplotlib import pyplot as plt 
import numpy as np
from google.colab.patches import cv2_imshow
img1 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/image/275x322.png')
img2 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/image/275x322.jpg')
dst1 = cv2.addWeighted(img1,0.1,img2,0.9,0)
dst2 = cv2.addWeighted(img1,0.2,img2,0.8,0)
dst3 = cv2.addWeighted(img1,0.3,img2,0.7,0)
dst4 = cv2.addWeighted(img1,0.4,img2,0.6,0)
dst5 = cv2.addWeighted(img1,0.5,img2,0.5,0)
dst6 = cv2.addWeighted(img1,0.6,img2,0.4,0)
dst7 = cv2.addWeighted(img1,0.7,img2,0.3,0)
dst8 = cv2.addWeighted(img1,0.8,img2,0.2,0)
dst9 = cv2.addWeighted(img1,0.9,img2,0.1,0)
cv2_imshow(img2)
cv2_imshow(dst1)
cv2_imshow(dst2)
cv2_imshow(dst3)
cv2_imshow(dst4)
cv2_imshow(dst5)
cv2_imshow(dst6)
cv2_imshow(dst7)
cv2_imshow(dst8)
cv2_imshow(dst9)
cv2_imshow(img1)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=275x322 at 0x7F4749743518>
# <PIL.Image.Image image mode=RGB size=275x322 at 0x7F4749743358>
# <PIL.Image.Image image mode=RGB size=275x322 at 0x7F47497433C8>
# <PIL.Image.Image image mode=RGB size=275x322 at 0x7F47497437F0>
# <PIL.Image.Image image mode=RGB size=275x322 at 0x7F4749743A90>
# <PIL.Image.Image image mode=RGB size=275x322 at 0x7F4749743358>
# <PIL.Image.Image image mode=RGB size=275x322 at 0x7F47497438D0>
# <PIL.Image.Image image mode=RGB size=275x322 at 0x7F47497437F0>
# <PIL.Image.Image image mode=RGB size=275x322 at 0x7F4749743518>
# <PIL.Image.Image image mode=RGB size=275x322 at 0x7F47497438D0>
# <PIL.Image.Image image mode=RGB size=275x322 at 0x7F47497433C8>
